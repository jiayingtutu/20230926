# %%
a="I'm a student"
print(a)
# Out:
# I'm a student

# %%
x1 = float(input("輸入一個數字"))
y1 = float(input("輸入一個數字"))
x2 = float(input("輸入一個數字"))
y2 = float(input("輸入一個數字"))
distance = ((x1 - x2)**2 + (y1 - y2)**2)**0.5
print(distance)
# Out:
# 輸入一個數字2
# 輸入一個數字1
# 輸入一個數字5.5
# 輸入一個數字8
# 7.826237921249264

# %%
h = float(input("請輸入身高"))
w = float(input("請輸入體重"))
H = h/100
H*=H
w/=H
print(w)
print(int(w<18.5))
# Out:
# 請輸入身高160
# 請輸入體重50
# 19.531249999999996
# 0
