# %%
print("長庚大學\n醫學系\n詹佳穎")
# Out:
# 長庚大學
# 醫學系
# 詹佳穎

# %%
a = float(input("輸入一個數字"))
print(a>10)
# Out:
# 輸入一個數字9.5
# False

# %%
a=3
b=5
print(3**b)
# Out:
# 243

# %%
a=3
b=5
print(a!=b)
# Out:
# True

# %%
a=3
b=5
a/=b
print(a)
# Out:
# 0.6

# %%
a=3
b=5
a=a/b
print(a)
# Out:
# 0.6
